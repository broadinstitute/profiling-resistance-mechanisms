# %%
import pathlib
import pandas as pd

from pycytominer import feature_select
from pycytominer.cyto_utils import infer_cp_features

# %%
data_dir = pathlib.Path("../0.generate-profiles/profiles")
output_dir = pathlib.Path("data")
batches = {
    "2019_11_11_Batch4": ["WTmut04hWed", "WTmut04hTh"],
    "2019_11_19_Batch5": ["217755"],
    "2019_11_20_Batch6": ["217760", "217762"],
    "2019_11_22_Batch7": ["217766", "217768"]
}

profile_suffix = "_normalized.csv.gz"
drop_cols = ["Metadata_plate_filename"]

feature_select_opts = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blocklist",
    "drop_outliers",
]
corr_threshold = 0.8
na_cutoff = 0

# %%
dfs = []
for batch in batches:
    for plate in batches[batch]:
        profile_file = pathlib.Path(f"{data_dir}/{batch}/{plate}/{plate}{profile_suffix}")
        profile_df = pd.read_csv(profile_file)
        profile_df = profile_df.assign(
            Metadata_batch=batch, Metadata_clone_type="resistant"
        )
        
        if batch != "2019_11_11_Batch4":
            profile_df = profile_df.drop(drop_cols, axis="columns")
        
        print(infer_cp_features(profile_df, metadata=True))
        
        profile_df.loc[profile_df.Metadata_clone_number.str.contains("WT"), "Metadata_clone_type"] = "sensitive"
        dfs.append(profile_df)
# Out:
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']
# ['Metadata_plate_map_name', 'Metadata_clone_number', 'Metadata_plate_ID', 'Metadata_treatment', 'Metadata_Plate', 'Metadata_Well', 'Metadata_batch', 'Metadata_clone_type']

# %%
bulk_df = pd.concat(dfs, sort=False).reset_index(drop=True)

# Reorder features
feat = infer_cp_features(bulk_df)
meta = infer_cp_features(bulk_df, metadata=True)
bulk_df = bulk_df.reindex(meta + feat, axis="columns")

print(bulk_df.shape)
bulk_df.head()
# Out:
# (420, 3536)
#   Metadata_plate_map_name Metadata_clone_number  Metadata_plate_ID  \
# 0             WTmut04hWed                 BZ017             217744
# 1             WTmut04hWed                 WT002             217744
# 2             WTmut04hWed                 WT008             217744
# 3             WTmut04hWed                 WT009             217744
# 4             WTmut04hWed                 BZ018             217744
#
#   Metadata_treatment Metadata_Plate Metadata_Well     Metadata_batch  \
# 0               DMSO    WTmut04hWed           B02  2019_11_11_Batch4
# 1               DMSO    WTmut04hWed           B03  2019_11_11_Batch4
# 2               DMSO    WTmut04hWed           B04  2019_11_11_Batch4
# 3               DMSO    WTmut04hWed           B05  2019_11_11_Batch4
# 4               DMSO    WTmut04hWed           B06  2019_11_11_Batch4
#
#   Metadata_clone_type  Cells_AreaShape_Area  Cells_AreaShape_Center_X  ...  \
# 0           resistant             -0.339587                 -1.910937  ...
# 1           sensitive              0.617688                 -1.715722  ...
# 2           sensitive             -0.286907                 -0.284146  ...
# 3           sensitive             -0.670720                  0.301499  ...
# 4           resistant              0.437070                 -0.316682  ...
#
#    Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0                           1.624670                           1.620789
# 1                           1.506541                           1.515823
# 2                          -0.268834                          -0.296211
# 3                          -0.227733                          -0.254327
# 4                          -0.436134                          -0.400178
#
#    Nuclei_Texture_Variance_RNA_20_00  Nuclei_Texture_Variance_RNA_20_01  \
# 0                           1.480625                           1.570777
# 1                           1.550858                           1.562888
# 2                          -0.291480                          -0.240747
# 3                          -0.300410                          -0.319758
# 4                          -0.347382                          -0.253614
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                           1.473312                           1.557271
# 1                           1.557828                           1.559924
# 2                          -0.274642                          -0.216133
# 3                          -0.279814                          -0.362015
# 4                          -0.355295                          -0.240678
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                          1.627277                          1.607243
# 1                          1.525360                          1.506269
# 2                         -0.261745                         -0.272104
# 3                         -0.261662                         -0.246862
# 4                         -0.477345                         -0.469789
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                          1.629955                          1.628896
# 1                          1.503591                          1.520258
# 2                         -0.266434                         -0.274902
# 3                         -0.261455                         -0.247199
# 4                         -0.476312                         -0.461479
#
# [5 rows x 3536 columns]

# %%
bulk_df = feature_select(
    bulk_df,
    operation=feature_select_opts,
    na_cutoff=na_cutoff,
    corr_threshold=corr_threshold,
)

print(bulk_df.shape)
bulk_df.head()
# Out:
# (420, 162)
#   Metadata_plate_map_name Metadata_clone_number  Metadata_plate_ID  \
# 0             WTmut04hWed                 BZ017             217744
# 1             WTmut04hWed                 WT002             217744
# 2             WTmut04hWed                 WT008             217744
# 3             WTmut04hWed                 WT009             217744
# 4             WTmut04hWed                 BZ018             217744
#
#   Metadata_treatment Metadata_Plate Metadata_Well     Metadata_batch  \
# 0               DMSO    WTmut04hWed           B02  2019_11_11_Batch4
# 1               DMSO    WTmut04hWed           B03  2019_11_11_Batch4
# 2               DMSO    WTmut04hWed           B04  2019_11_11_Batch4
# 3               DMSO    WTmut04hWed           B05  2019_11_11_Batch4
# 4               DMSO    WTmut04hWed           B06  2019_11_11_Batch4
#
#   Metadata_clone_type  Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0           resistant                    -0.013031               -0.552375
# 1           sensitive                     0.540148               -0.688571
# 2           sensitive                    -1.801681                0.967419
# 3           sensitive                    -1.507963                1.590062
# 4           resistant                     1.363978               -1.787466
#
#    ...  Nuclei_RadialDistribution_RadialCV_RNA_1of4  \
# 0  ...                                    -0.036359
# 1  ...                                     0.524096
# 2  ...                                    -0.990714
# 3  ...                                     0.127708
# 4  ...                                     0.531589
#
#    Nuclei_Texture_Correlation_AGP_20_00  Nuclei_Texture_Correlation_AGP_20_03  \
# 0                              0.267998                             -0.479067
# 1                             -0.846893                             -0.886894
# 2                             -0.518431                             -0.545056
# 3                             -0.319850                              0.061250
# 4                             -0.152575                             -1.076457
#
#    Nuclei_Texture_Correlation_AGP_5_00  Nuclei_Texture_InfoMeas1_DNA_10_02  \
# 0                             0.432208                            1.294007
# 1                            -0.753365                            1.755599
# 2                             0.573946                            0.788443
# 3                            -1.289395                            0.918946
# 4                             0.280363                            1.182714
#
#    Nuclei_Texture_InfoMeas1_DNA_5_00  Nuclei_Texture_InfoMeas1_Mito_10_00  \
# 0                           1.070871                             0.454538
# 1                          -0.715581                             1.596588
# 2                          -0.418218                             1.101691
# 3                           1.180027                             1.093350
# 4                          -0.153243                            -0.138147
#
#    Nuclei_Texture_InfoMeas1_Mito_5_00  Nuclei_Texture_InfoMeas2_DNA_5_00  \
# 0                           -0.388005                          -1.567204
# 1                           -0.130438                           0.000068
# 2                           -0.314686                          -0.023801
# 3                            1.125821                          -1.388672
# 4                           -1.455125                          -0.593253
#
#    Nuclei_Texture_SumAverage_DNA_20_00
# 0                            -1.124995
# 1                            -1.114912
# 2                            -0.090529
# 3                            -0.277860
# 4                            -1.372097
#
# [5 rows x 162 columns]

# %%
output_file = pathlib.Path(f"{output_dir}/bulk_profiles_four_clone.csv.gz")
bulk_df.to_csv(output_file, sep=",", compression="gzip", index=False)
