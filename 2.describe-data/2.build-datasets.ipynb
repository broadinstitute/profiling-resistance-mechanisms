# %% [markdown]
# # Combine Specific Batches for Downstream Experiments
#
# Here, I combine batches 1 (20X) and 2 because they measure clones A and E.
# I also combine batches 5, 6, and 7. These platemaps are all the same, and each measure 8 different wild-type and mutant clones.

# %%
import os
import pandas as pd

from pycytominer import feature_select, write_gct
from pycytominer.cyto_utils import infer_cp_features

from scripts.processing_utils import load_data

# %%
# Set constants
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blacklist",
    "drop_outliers"
]
profile_dir = os.path.join("..", "0.generate-profiles", "profiles")
gct_dir = os.path.join("data", "gct_files")
output_dir = os.path.join("data", "merged")

suffix = "normalized.csv.gz"

batches = [x for x in os.listdir(profile_dir) if x != ".DS_Store"]
batches
# Out:
# ['2019_02_15_Batch1_40X',
#  '2019_03_20_Batch2',
#  '2019_06_25_Batch3',
#  '2019_11_11_Batch4',
#  '2019_11_20_Batch6',
#  '2019_02_15_Batch1_20X',
#  '2019_11_19_Batch5',
#  '2019_11_22_Batch7']

# %%
dataset_a = ["2019_02_15_Batch1_20X", "2019_03_20_Batch2"]
dataset_b = ["2019_11_19_Batch5", "2019_11_20_Batch6", "2019_11_22_Batch7"]

# %%
dataset_a_dict = {}
dataset_b_dict = {}
for batch in batches:    

    if batch in dataset_a:
        dataset_a_dict[batch] = load_data(
            batch=batch, suffix=suffix, profile_dir=profile_dir, combine_dfs=True
        )
        
    if batch in dataset_b:
        dataset_b_dict[batch] = load_data(
            batch=batch, suffix=suffix, profile_dir=profile_dir, combine_dfs=True
        )

# %% [markdown]
# ## Process and Output Dataset A

# %%
dataset_a_df = pd.concat(dataset_a_dict.values()).reset_index(drop=True)
dataset_a_df = dataset_a_df.assign(Metadata_clone_type="resistant")
dataset_a_df.loc[dataset_a_df.Metadata_CellLine.str.contains("WT"), "Metadata_clone_type"] = "wildtype"

meta_cols = infer_cp_features(dataset_a_df, metadata=True)
cp_cols = infer_cp_features(dataset_a_df)

dataset_a_df = dataset_a_df.reindex(meta_cols + cp_cols, axis="columns")

print(dataset_a_df.shape)
dataset_a_df.head()
# Out:
# (72, 3535)
#   Metadata_CellLine  Metadata_Dosage      Metadata_Plate Metadata_Well  \
# 0                WT              0.0  207106_exposure320           B02
# 1                WT              0.0  207106_exposure320           B03
# 2                WT              0.0  207106_exposure320           B04
# 3            CloneA              0.0  207106_exposure320           B05
# 4            CloneA              0.0  207106_exposure320           B06
#
#       Metadata_batch      Metadata_plate_map_name Metadata_clone_type  \
# 0  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 1  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 2  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 3  2019_03_20_Batch2  PlateMap_207106_exposure320           resistant
# 4  2019_03_20_Batch2  PlateMap_207106_exposure320           resistant
#
#    Cells_AreaShape_Area  Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0             -0.239970                  0.774097                  0.981307
# 1             -0.324702                 -1.704724                  0.793306
# 2             -0.283277                  1.097421                  0.998398
# 3             -2.162447                  0.789493                 -0.471426
# 4             -1.269935                 -0.365237                 -0.830337
#
#    ...  Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0  ...                          -0.460955                          -0.471566
# 1  ...                          -0.407693                          -0.409836
# 2  ...                          -0.418464                          -0.430647
# 3  ...                          -0.821523                          -0.818418
# 4  ...                          -0.862363                          -0.858491
#
#    Nuclei_Texture_Variance_RNA_20_00  Nuclei_Texture_Variance_RNA_20_01  \
# 0                          -0.472902                          -0.463908
# 1                          -0.418750                          -0.400586
# 2                          -0.440995                          -0.442150
# 3                          -0.812761                          -0.830032
# 4                          -0.852563                          -0.877956
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                          -0.491301                          -0.491651
# 1                          -0.431729                          -0.435196
# 2                          -0.445753                          -0.467471
# 3                          -0.805281                          -0.798594
# 4                          -0.843264                          -0.838066
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                         -0.465130                         -0.463746
# 1                         -0.407739                         -0.408274
# 2                         -0.423247                         -0.419649
# 3                         -0.821887                         -0.822436
# 4                         -0.863207                         -0.863628
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                         -0.458918                         -0.461595
# 1                         -0.404893                         -0.403287
# 2                         -0.414115                         -0.415869
# 3                         -0.825891                         -0.824499
# 4                         -0.867076                         -0.866256
#
# [5 rows x 3535 columns]

# %%
pd.crosstab(
    dataset_a_df.Metadata_CellLine,
    dataset_a_df.Metadata_Dosage
)
# Out:
# Metadata_Dosage    0.0   0.7   7.0   70.0
# Metadata_CellLine
# CloneA                6     6     6     6
# CloneE                6     6     6     6
# WT                    6     6     6     6

# %%
dataset_a_name = "combined_cloneAcloneE_dataset"

# %%
dataset_a_featureselect_df = feature_select(dataset_a_df, operation=feature_select_ops)

output_file = os.path.join(output_dir, "{}.csv".format(dataset_a_name))
dataset_a_featureselect_df.to_csv(output_file, index=False)

output_gct_file = os.path.join(gct_dir, "{}.gct".format(dataset_a_name))
write_gct(profiles=dataset_a_featureselect_df, output_file=output_gct_file)

print(dataset_a_featureselect_df.shape)
dataset_a_featureselect_df.head()
# Out:
# (72, 252)
#   Metadata_CellLine  Metadata_Dosage      Metadata_Plate Metadata_Well  \
# 0                WT              0.0  207106_exposure320           B02
# 1                WT              0.0  207106_exposure320           B03
# 2                WT              0.0  207106_exposure320           B04
# 3            CloneA              0.0  207106_exposure320           B05
# 4            CloneA              0.0  207106_exposure320           B06
#
#       Metadata_batch      Metadata_plate_map_name Metadata_clone_type  \
# 0  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 1  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 2  2019_03_20_Batch2  PlateMap_207106_exposure320            wildtype
# 3  2019_03_20_Batch2  PlateMap_207106_exposure320           resistant
# 4  2019_03_20_Batch2  PlateMap_207106_exposure320           resistant
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Orientation  \
# 0                     1.325917                     0.350969
# 1                     1.164187                    -0.054254
# 2                     1.127666                     1.699161
# 3                     0.493556                    -0.138822
# 4                     0.498403                    -0.706464
#
#    Cells_AreaShape_Solidity  ...  Nuclei_Texture_Correlation_DNA_10_03  \
# 0                 -0.701823  ...                              0.635602
# 1                 -0.788705  ...                              0.988743
# 2                 -0.617913  ...                              0.581176
# 3                 -1.206096  ...                              1.257560
# 4                 -1.140831  ...                              1.196471
#
#    Nuclei_Texture_Correlation_ER_10_01  Nuclei_Texture_Correlation_ER_20_03  \
# 0                            -0.115739                             0.654788
# 1                            -0.196532                             0.975687
# 2                             0.158584                             0.626946
# 3                            -1.407506                             1.688787
# 4                            -1.062395                             1.369196
#
#    Nuclei_Texture_Correlation_Mito_10_03  \
# 0                              -0.243628
# 1                              -0.225656
# 2                              -0.214842
# 3                              -0.332457
# 4                              -0.334405
#
#    Nuclei_Texture_Correlation_Mito_20_00  \
# 0                               -0.03042
# 1                               -0.03042
# 2                               -0.03042
# 3                               -0.03042
# 4                               -0.03042
#
#    Nuclei_Texture_Correlation_RNA_10_01  Nuclei_Texture_Correlation_RNA_10_02  \
# 0                             -0.039547                              0.162129
# 1                             -0.068849                             -0.170842
# 2                             -0.163731                             -0.087247
# 3                             -1.440942                             -1.480886
# 4                             -1.480594                             -1.303818
#
#    Nuclei_Texture_Correlation_RNA_10_03  Nuclei_Texture_Correlation_RNA_20_00  \
# 0                              0.484300                              1.172104
# 1                              0.523793                              1.172104
# 2                              0.457444                              0.766137
# 3                             -0.494817                              1.172104
# 4                             -0.425634                              0.762304
#
#    Nuclei_Texture_SumVariance_ER_20_01
# 0                            -0.643649
# 1                            -0.634201
# 2                            -0.628041
# 3                            -1.165874
# 4                            -1.078278
#
# [5 rows x 252 columns]

# %% [markdown]
# ## Process and Output Dataset B

# %%
dataset_b_df = pd.concat(dataset_b_dict.values()).reset_index(drop=True)

dataset_b_df = dataset_b_df.assign(Metadata_clone_type="resistant")
dataset_b_df.loc[dataset_b_df.Metadata_clone_number.str.contains("WT"), "Metadata_clone_type"] = "wildtype"

meta_cols = infer_cp_features(dataset_b_df, metadata=True)
cp_cols = infer_cp_features(dataset_b_df)

dataset_b_df = dataset_b_df.reindex(meta_cols + cp_cols, axis="columns")

print(dataset_b_df.shape)
dataset_b_df.head()
# Out:
# (300, 3537)
#    Metadata_Plate Metadata_Well     Metadata_batch Metadata_clone_number  \
# 0          217760           B02  2019_11_20_Batch6                 BZ017
# 1          217760           B03  2019_11_20_Batch6                 WT002
# 2          217760           B04  2019_11_20_Batch6                 WT008
# 3          217760           B05  2019_11_20_Batch6                 WT009
# 4          217760           B06  2019_11_20_Batch6                 BZ018
#
#    Metadata_plate_ID      Metadata_plate_filename  Metadata_plate_map_name  \
# 0             217760  20191120-20191115-HiDensity                   217760
# 1             217760  20191120-20191115-HiDensity                   217760
# 2             217760  20191120-20191115-HiDensity                   217760
# 3             217760  20191120-20191115-HiDensity                   217760
# 4             217760  20191120-20191115-HiDensity                   217760
#
#   Metadata_treatment Metadata_clone_type  Cells_AreaShape_Area  ...  \
# 0               DMSO           resistant             -0.409916  ...
# 1               DMSO            wildtype             -0.137631  ...
# 2               DMSO            wildtype             -0.739635  ...
# 3               DMSO            wildtype              0.938743  ...
# 4               DMSO           resistant             -0.858759  ...
#
#    Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0                           1.033520                           1.007700
# 1                           0.142262                           0.094713
# 2                          -0.138435                          -0.159706
# 3                           0.676709                           0.694346
# 4                           0.148026                           0.157586
#
#    Nuclei_Texture_Variance_RNA_20_00  Nuclei_Texture_Variance_RNA_20_01  \
# 0                           0.920125                           0.870170
# 1                           0.156082                           0.038916
# 2                          -0.178242                          -0.134872
# 3                           0.798707                           0.716014
# 4                           0.030911                           0.091131
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                           0.924758                           0.886717
# 1                           0.135246                          -0.042784
# 2                          -0.183906                          -0.125331
# 3                           0.783981                           0.733235
# 4                           0.037021                           0.118609
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                          1.006241                          1.009751
# 1                          0.107654                          0.125698
# 2                         -0.121369                         -0.134951
# 3                          0.640209                          0.675864
# 4                          0.149601                          0.152945
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                          1.015261                          1.031261
# 1                          0.115468                          0.136594
# 2                         -0.127765                         -0.129745
# 3                          0.653471                          0.677681
# 4                          0.151491                          0.143787
#
# [5 rows x 3537 columns]

# %%
dataset_b_df.Metadata_clone_number.value_counts()
# Out:
# WT_parental    60
# WT002          30
# WT008          30
# BZ018          30
# BZ008          30
# WT011          30
# WT009          30
# BZ001          30
# BZ017          30
# Name: Metadata_clone_number, dtype: int64

# %%
dataset_b_name = "combined_four_clone_dataset"

# %%
dataset_b_featureselect_df = feature_select(dataset_b_df, operation=feature_select_ops)

output_file = os.path.join(output_dir, "{}.csv".format(dataset_b_name))
dataset_b_featureselect_df.to_csv(output_file, index=False)

output_gct_file = os.path.join(gct_dir, "{}.gct".format(dataset_b_name))
write_gct(profiles=dataset_b_featureselect_df, output_file=output_gct_file)

print(dataset_b_featureselect_df.shape)
dataset_b_featureselect_df.head()
# Out:
# (300, 315)
#    Metadata_Plate Metadata_Well     Metadata_batch Metadata_clone_number  \
# 0          217760           B02  2019_11_20_Batch6                 BZ017
# 1          217760           B03  2019_11_20_Batch6                 WT002
# 2          217760           B04  2019_11_20_Batch6                 WT008
# 3          217760           B05  2019_11_20_Batch6                 WT009
# 4          217760           B06  2019_11_20_Batch6                 BZ018
#
#    Metadata_plate_ID      Metadata_plate_filename  Metadata_plate_map_name  \
# 0             217760  20191120-20191115-HiDensity                   217760
# 1             217760  20191120-20191115-HiDensity                   217760
# 2             217760  20191120-20191115-HiDensity                   217760
# 3             217760  20191120-20191115-HiDensity                   217760
# 4             217760  20191120-20191115-HiDensity                   217760
#
#   Metadata_treatment Metadata_clone_type  Cells_AreaShape_Compactness  ...  \
# 0               DMSO           resistant                     0.189274  ...
# 1               DMSO            wildtype                    -0.222248  ...
# 2               DMSO            wildtype                    -1.257285  ...
# 3               DMSO            wildtype                    -1.611328  ...
# 4               DMSO           resistant                     0.790436  ...
#
#    Nuclei_Texture_Correlation_Mito_10_00  \
# 0                               0.111782
# 1                              -0.991681
# 2                              -0.507651
# 3                               0.745114
# 4                               0.300582
#
#    Nuclei_Texture_Correlation_Mito_20_02  \
# 0                               0.804833
# 1                               0.393211
# 2                               0.040824
# 3                               0.021943
# 4                               0.429726
#
#    Nuclei_Texture_Correlation_Mito_20_03  \
# 0                               0.432627
# 1                               1.634457
# 2                               0.691947
# 3                               0.097973
# 4                              -0.433379
#
#    Nuclei_Texture_Correlation_RNA_10_01  Nuclei_Texture_Correlation_RNA_20_02  \
# 0                              0.666170                              0.733860
# 1                             -0.471892                             -0.098693
# 2                             -0.156254                              0.201488
# 3                              1.251972                             -0.309386
# 4                              0.677186                              0.750527
#
#    Nuclei_Texture_Entropy_DNA_20_03  Nuclei_Texture_InfoMeas1_DNA_5_02  \
# 0                         -1.418330                           0.118819
# 1                         -1.155697                          -0.089767
# 2                         -0.989994                           0.401930
# 3                         -0.094936                          -1.829349
# 4                         -0.828520                           0.151016
#
#    Nuclei_Texture_InfoMeas1_ER_20_03  Nuclei_Texture_InfoMeas1_Mito_5_00  \
# 0                          -0.374701                           -0.641564
# 1                           1.499978                            1.406381
# 2                           0.649963                            0.101806
# 3                          -0.156229                           -0.504957
# 4                          -0.778626                           -1.104598
#
#    Nuclei_Texture_SumAverage_DNA_20_01
# 0                            -1.796205
# 1                            -1.375335
# 2                            -0.077520
# 3                            -1.876129
# 4                            -0.295274
#
# [5 rows x 315 columns]
