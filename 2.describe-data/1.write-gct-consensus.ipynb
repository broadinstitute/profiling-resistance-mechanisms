# %% [markdown]
# ## Write all Profiles to GCT for Heatmap Visualization
#
# **Gregory Way, 2020**
#
# I also build consensus signatures for all unique treatments and output associated files.

# %%
import os
import pandas as pd

from pycytominer import (
    feature_select,
    write_gct
)

from pycytominer.consensus import modz
from pycytominer.cyto_utils import infer_cp_features

from scripts.processing_utils import load_data

# %%
# Set constants
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blacklist",
    "drop_outliers"
]
gct_dir = os.path.join("data", "gct_files")
profile_dir = os.path.join("..", "0.generate-profiles", "profiles")
cell_count_dir = os.path.join("..", "0.generate-profiles", "cell_counts")
output_dir = os.path.join("data", "merged")

suffix = "normalized.csv.gz"

batches = [x for x in os.listdir(profile_dir) if x != ".DS_Store"]
batches
# Out:
# ['2019_02_15_Batch1_40X',
#  '2019_03_20_Batch2',
#  '2019_06_25_Batch3',
#  '2019_11_11_Batch4',
#  '2019_11_20_Batch6',
#  '2019_02_15_Batch1_20X',
#  '2019_11_19_Batch5',
#  '2019_11_22_Batch7']

# %%
profile_batches = {}
for batch in batches:
    # Build output information
    output_gct_dir = os.path.join(gct_dir, batch)
    os.makedirs(output_gct_dir, exist_ok=True)
    output_gct_file = os.path.join(
        output_gct_dir, "{}_feature_select.gct".format(batch)
    )
    
    # Load the profile data and add cell counts
    df = load_data(
        batch=batch,
        suffix=suffix,
        profile_dir=profile_dir,
        combine_dfs=True,
        add_cell_count=True,
        cell_count_dir=cell_count_dir
    )
    
    # Save normalized and non-feature selected data
    profile_batches[batch] = df
    
    # Apply feature selection again - this is particularly important for batches
    # with multiple plates
    df = feature_select(df, operation=feature_select_ops)
    
    # Write the dataframe as a gct file for input into Morpheus
    write_gct(profiles=df, output_file=output_gct_file)

# %% [markdown]
# ## Merge Profiles Together and Output

# %%
all_profiles_df = pd.concat(profile_batches.values(), sort=True).reset_index(drop=True)

meta_features = infer_cp_features(all_profiles_df, metadata=True)
cp_cols = infer_cp_features(all_profiles_df, metadata=False)

all_profiles_df = all_profiles_df.reindex(meta_features + cp_cols, axis="columns")

print(all_profiles_df.shape)
all_profiles_df.head()
# Out:
# (10062, 4334)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate  Metadata_Site  \
# 0                WT              0.0  HCT116bortezomib              1
# 1                WT              0.0  HCT116bortezomib              2
# 2                WT              0.0  HCT116bortezomib              3
# 3                WT              0.0  HCT116bortezomib              4
# 4                WT              0.0  HCT116bortezomib              5
#
#   Metadata_Well         Metadata_batch  Metadata_cell_count  \
# 0           B03  2019_02_15_Batch1_40X                  387
# 1           B03  2019_02_15_Batch1_40X                  377
# 2           B03  2019_02_15_Batch1_40X                  403
# 3           B03  2019_02_15_Batch1_40X                  414
# 4           B03  2019_02_15_Batch1_40X                  413
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  ...  \
# 0                   NaN                NaN                     NaN  ...
# 1                   NaN                NaN                     NaN  ...
# 2                   NaN                NaN                     NaN  ...
# 3                   NaN                NaN                     NaN  ...
# 4                   NaN                NaN                     NaN  ...
#
#   Nuclei_Texture_Variance_RNA_20_02 Nuclei_Texture_Variance_RNA_20_03  \
# 0                         -1.247347                         -1.240386
# 1                         -1.092795                         -1.098571
# 2                         -0.827655                         -0.818969
# 3                         -0.873986                         -0.903269
# 4                         -0.875399                         -0.871332
#
#    Nuclei_Texture_Variance_RNA_50_00  Nuclei_Texture_Variance_RNA_50_01  \
# 0                          -1.041955                          -1.014310
# 1                          -1.335448                          -1.209457
# 2                          -0.834124                          -0.949275
# 3                          -1.046058                          -1.094919
# 4                          -1.335448                          -1.209457
#
#    Nuclei_Texture_Variance_RNA_50_02  Nuclei_Texture_Variance_RNA_50_03  \
# 0                          -1.081468                          -1.040797
# 1                          -1.328965                          -1.213524
# 2                          -0.808757                          -0.842403
# 3                          -1.035641                          -1.136826
# 4                          -1.328965                          -1.213524
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 4334 columns]

# %%
all_profiles_df = feature_select(all_profiles_df, operation=feature_select_ops)

print(all_profiles_df.shape)
all_profiles_df.head()
# Out:
# (10062, 317)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate  Metadata_Site  \
# 0                WT              0.0  HCT116bortezomib              1
# 1                WT              0.0  HCT116bortezomib              2
# 2                WT              0.0  HCT116bortezomib              3
# 3                WT              0.0  HCT116bortezomib              4
# 4                WT              0.0  HCT116bortezomib              5
#
#   Metadata_Well         Metadata_batch  Metadata_cell_count  \
# 0           B03  2019_02_15_Batch1_40X                  387
# 1           B03  2019_02_15_Batch1_40X                  377
# 2           B03  2019_02_15_Batch1_40X                  403
# 3           B03  2019_02_15_Batch1_40X                  414
# 4           B03  2019_02_15_Batch1_40X                  413
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  ...  \
# 0                   NaN                NaN                     NaN  ...
# 1                   NaN                NaN                     NaN  ...
# 2                   NaN                NaN                     NaN  ...
# 3                   NaN                NaN                     NaN  ...
# 4                   NaN                NaN                     NaN  ...
#
#   Nuclei_Texture_Correlation_Mito_20_02 Nuclei_Texture_Correlation_RNA_20_01  \
# 0                             -0.470456                             0.048037
# 1                             -0.487478                             0.199301
# 2                             -0.191161                             0.230228
# 3                             -0.678452                            -1.460303
# 4                             -0.356237                             0.206316
#
#    Nuclei_Texture_Correlation_RNA_20_03  Nuclei_Texture_InfoMeas1_DNA_10_01  \
# 0                             -1.021192                            1.280061
# 1                             -0.794176                            1.477292
# 2                             -1.095142                            1.245091
# 3                             -0.935530                            1.141819
# 4                             -0.867236                            0.892838
#
#    Nuclei_Texture_InfoMeas1_DNA_10_02  Nuclei_Texture_InfoMeas1_DNA_20_02  \
# 0                            1.173100                            1.179094
# 1                            1.348551                            1.197780
# 2                            1.064989                            1.163397
# 3                            1.511604                            1.186359
# 4                            1.125734                            0.768944
#
#    Nuclei_Texture_InfoMeas1_ER_20_03  Nuclei_Texture_InfoMeas1_Mito_10_00  \
# 0                           0.604495                             0.491350
# 1                           0.262709                             0.232968
# 2                           0.323375                             0.409219
# 3                           0.509416                             0.655411
# 4                           0.448945                             0.731992
#
#    Nuclei_Texture_InfoMeas1_Mito_10_01  Nuclei_Texture_InfoMeas1_Mito_20_03
# 0                             0.554789                             0.631287
# 1                             0.361193                            -0.160685
# 2                             0.308227                             0.106943
# 3                             0.704067                             0.272486
# 4                             0.620672                             0.133346
#
# [5 rows x 317 columns]

# %%
output_file = os.path.join(output_dir, "all_merged_profiles.csv.gz")
all_profiles_df.to_csv(output_file, index=False, compression="gzip")

# %% [markdown]
# ## Generate Consensus Signatures

# %%
consensus_data = {}
for batch in profile_batches:
    meta_features = infer_cp_features(profile_batches[batch], metadata=True)
    meta_features = [x for x in meta_features if "well" not in x.lower()]
    meta_features = [x for x in meta_features if "site" not in x.lower()]
    
    consensus_df = (
        profile_batches[batch]
        .groupby(meta_features)
        .median()
        .drop("Metadata_Site", axis="columns")
        .reset_index(drop=False)
    )
    
    consensus_data[batch] = consensus_df.reset_index()

# %%
full_consensus_df = (
    pd.concat(consensus_data.values(), sort=True)
    .reset_index(drop=True)
)

meta_features = infer_cp_features(full_consensus_df, metadata=True)
cp_cols = infer_cp_features(full_consensus_df, metadata=False)

full_consensus_df = (
    full_consensus_df
    .reindex(meta_features + cp_cols, axis="columns")
    .drop("Metadata_cell_count", axis="columns")
)

print(full_consensus_df.shape)
full_consensus_df.head()
# Out:
# (9548, 4331)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate         Metadata_batch  \
# 0            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 1            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 2            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 3            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 4            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  \
# 0                   NaN                NaN                     NaN
# 1                   NaN                NaN                     NaN
# 2                   NaN                NaN                     NaN
# 3                   NaN                NaN                     NaN
# 4                   NaN                NaN                     NaN
#
#      Metadata_plate_map_name Metadata_treatment  Cells_AreaShape_Area  ...  \
# 0  PlateMap_HCT116bortezomib                NaN              0.445480  ...
# 1  PlateMap_HCT116bortezomib                NaN              0.214707  ...
# 2  PlateMap_HCT116bortezomib                NaN             -0.180964  ...
# 3  PlateMap_HCT116bortezomib                NaN              0.045045  ...
# 4  PlateMap_HCT116bortezomib                NaN              0.046495  ...
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                          -1.062497                          -1.059947
# 1                          -0.909872                          -0.926507
# 2                          -1.032693                          -1.033343
# 3                          -1.043915                          -1.013009
# 4                          -1.239337                          -1.241671
#
#    Nuclei_Texture_Variance_RNA_50_00  Nuclei_Texture_Variance_RNA_50_01  \
# 0                          -0.748613                          -0.619886
# 1                          -0.688900                          -0.593487
# 2                          -0.650021                          -0.503968
# 3                          -0.735652                          -0.585777
# 4                          -0.971648                          -0.943969
#
#    Nuclei_Texture_Variance_RNA_50_02  Nuclei_Texture_Variance_RNA_50_03  \
# 0                          -0.726331                          -0.678380
# 1                          -0.693049                          -0.613265
# 2                          -0.680283                          -0.444709
# 3                          -0.692562                          -0.619315
# 4                          -0.984278                          -1.002060
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 4331 columns]

# %%
consensus_df = feature_select(full_consensus_df, operation=feature_select_ops)

print(consensus_df.shape)
consensus_df.head()
# Out:
# (9548, 311)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate         Metadata_batch  \
# 0            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 1            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 2            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 3            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
# 4            CloneA              0.0  HCT116bortezomib  2019_02_15_Batch1_40X
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  \
# 0                   NaN                NaN                     NaN
# 1                   NaN                NaN                     NaN
# 2                   NaN                NaN                     NaN
# 3                   NaN                NaN                     NaN
# 4                   NaN                NaN                     NaN
#
#      Metadata_plate_map_name Metadata_treatment  Cells_AreaShape_Eccentricity  \
# 0  PlateMap_HCT116bortezomib                NaN                      0.215897
# 1  PlateMap_HCT116bortezomib                NaN                      0.516477
# 2  PlateMap_HCT116bortezomib                NaN                      0.547577
# 3  PlateMap_HCT116bortezomib                NaN                      0.737125
# 4  PlateMap_HCT116bortezomib                NaN                      1.262829
#
#    ...  Nuclei_Texture_Correlation_Mito_20_02  \
# 0  ...                              -0.843256
# 1  ...                              -0.861476
# 2  ...                              -0.990443
# 3  ...                              -0.813235
# 4  ...                              -0.837698
#
#    Nuclei_Texture_Correlation_RNA_20_01  Nuclei_Texture_Correlation_RNA_20_03  \
# 0                             -1.310903                              0.412465
# 1                             -0.481976                              0.089565
# 2                              0.025102                             -0.565973
# 3                             -0.144382                             -0.765505
# 4                             -0.410006                             -1.624857
#
#    Nuclei_Texture_InfoMeas1_DNA_10_01  Nuclei_Texture_InfoMeas1_DNA_10_02  \
# 0                            1.143640                            0.775286
# 1                            0.847193                            0.797284
# 2                            0.984887                            0.883996
# 3                            0.925841                            0.936260
# 4                            1.126458                            1.357034
#
#    Nuclei_Texture_InfoMeas1_DNA_20_02  Nuclei_Texture_InfoMeas1_ER_20_03  \
# 0                            0.981503                           1.541588
# 1                            1.065048                           1.468746
# 2                            1.116078                           1.896790
# 3                            1.154712                           1.706626
# 4                            1.128997                           1.131859
#
#    Nuclei_Texture_InfoMeas1_Mito_10_00  Nuclei_Texture_InfoMeas1_Mito_10_01  \
# 0                             0.960230                             1.194925
# 1                             0.880934                             0.939595
# 2                             1.077582                             1.299896
# 3                             1.223876                             1.217978
# 4                             1.017592                             1.068580
#
#    Nuclei_Texture_InfoMeas1_Mito_20_03
# 0                             1.028573
# 1                             0.841810
# 2                             1.482821
# 3                             1.327418
# 4                             0.934690
#
# [5 rows x 311 columns]

# %%
output_gct_file = os.path.join(gct_dir, "consensus_feature_select.gct")
write_gct(profiles=consensus_df, output_file=output_gct_file)
