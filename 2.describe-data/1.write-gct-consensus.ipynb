# %% [markdown]
# ## Write all Profiles to GCT for Heatmap Visualization
#
# **Gregory Way, 2020**
#
# I also build consensus signatures for all unique treatments and output associated files.

# %%
import os
import pandas as pd

from pycytominer import (
    feature_select,
    write_gct
)

from pycytominer.consensus import modz
from pycytominer.cyto_utils import infer_cp_features

from scripts.processing_utils import load_data

# %%
# Set constants
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blacklist",
    "drop_outliers"
]
gct_dir = os.path.join("data", "gct_files")
profile_dir = os.path.join("..", "0.generate-profiles", "profiles")
cell_count_dir = os.path.join("..", "0.generate-profiles", "cell_counts")
output_dir = os.path.join("data", "merged")

suffix = "normalized.csv.gz"

batches = [x for x in os.listdir(profile_dir) if x != ".DS_Store"]
batches
# Out:
# ['2019_02_15_Batch1_40X',
#  '2019_03_20_Batch2',
#  '2019_06_25_Batch3',
#  '2019_11_11_Batch4',
#  '2019_11_20_Batch6',
#  '2019_02_15_Batch1_20X',
#  '2019_11_19_Batch5',
#  '2019_11_22_Batch7']

# %%
profile_batches = {}
for batch in batches:
    # Build output information
    output_gct_dir = os.path.join(gct_dir, batch)
    os.makedirs(output_gct_dir, exist_ok=True)
    output_gct_file = os.path.join(
        output_gct_dir, "{}_feature_select.gct".format(batch)
    )
    
    # Load the profile data
    df = load_data(
        batch=batch, suffix=suffix, profile_dir=profile_dir, combine_dfs=True
    )
    
    # Save normalized and non-feature selected data
    profile_batches[batch] = df
    
    # Apply feature selection again - this is particularly important for batches
    # with multiple plates
    df = feature_select(df, operation=feature_select_ops)
    
    # Load cell counts for the specific plates
    count_files = [
        os.path.join(cell_count_dir, x) for x in os.listdir(cell_count_dir) if batch in x
    ]   
    all_plate_dfs = []
    for count_file in count_files:
        plate = os.path.basename(count_file)
        plate = plate.replace(batch, "").replace("cell_count.tsv", "").strip("_")

        plate_df = (
            pd.read_csv(count_file, sep='\t')
            .rename(
                {
                    plate: "Metadata_cell_count"
                },
                axis="columns"
            )
        )
        all_plate_dfs.append(plate_df)

    # Merge all plates and append cell count information as a metadata feature
    plate_df = pd.concat(all_plate_dfs, sort=True)
    df = (
        plate_df
        .merge(
            df,
            on=plate_df.drop("Metadata_cell_count", axis="columns").columns.tolist()
        )
    )
    
    # Write the dataframe as a gct file for input into Morpheus
    write_gct(profiles=df, output_file=output_gct_file)

# %% [markdown]
# ## Merge Profiles Together and Output

# %%
all_profiles_df = pd.concat(profile_batches.values(), sort=True).reset_index(drop=True)

meta_features = infer_cp_features(all_profiles_df, metadata=True)
cp_cols = infer_cp_features(all_profiles_df, metadata=False)

all_profiles_df = all_profiles_df.reindex(meta_features + cp_cols, axis="columns")

print(all_profiles_df.shape)
all_profiles_df.head()
# Out:
# (633, 4331)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate Metadata_Well  \
# 0                WT              0.0  HCT116bortezomib           B03
# 1                WT              0.0  HCT116bortezomib           B04
# 2                WT              0.0  HCT116bortezomib           B05
# 3            CloneA              0.0  HCT116bortezomib           B06
# 4            CloneA              0.0  HCT116bortezomib           B07
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  \
# 0                   NaN                NaN                     NaN
# 1                   NaN                NaN                     NaN
# 2                   NaN                NaN                     NaN
# 3                   NaN                NaN                     NaN
# 4                   NaN                NaN                     NaN
#
#      Metadata_plate_map_name Metadata_treatment  Cells_AreaShape_Area  ...  \
# 0  PlateMap_HCT116bortezomib                NaN             -1.665382  ...
# 1  PlateMap_HCT116bortezomib                NaN             -1.424351  ...
# 2  PlateMap_HCT116bortezomib                NaN             -1.138526  ...
# 3  PlateMap_HCT116bortezomib                NaN             -0.928542  ...
# 4  PlateMap_HCT116bortezomib                NaN             -1.053205  ...
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                          -1.000830                          -1.008630
# 1                          -0.670609                          -0.675413
# 2                          -0.693224                          -0.706368
# 3                          -0.967157                          -0.970770
# 4                          -1.157542                          -1.152628
#
#    Nuclei_Texture_Variance_RNA_50_00  Nuclei_Texture_Variance_RNA_50_01  \
# 0                          -1.051993                          -1.100879
# 1                          -0.850818                          -0.924916
# 2                          -0.791450                          -0.815241
# 3                          -0.902676                          -0.905242
# 4                          -1.160002                          -1.135083
#
#    Nuclei_Texture_Variance_RNA_50_02  Nuclei_Texture_Variance_RNA_50_03  \
# 0                          -1.069711                          -1.109150
# 1                          -0.861662                          -0.933925
# 2                          -0.774766                          -0.826583
# 3                          -0.901244                          -0.873114
# 4                          -1.150242                          -1.109386
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 4331 columns]

# %%
all_profiles_df = feature_select(all_profiles_df, operation=feature_select_ops)

print(all_profiles_df.shape)
all_profiles_df.head()
# Out:
# (633, 283)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate Metadata_Well  \
# 0                WT              0.0  HCT116bortezomib           B03
# 1                WT              0.0  HCT116bortezomib           B04
# 2                WT              0.0  HCT116bortezomib           B05
# 3            CloneA              0.0  HCT116bortezomib           B06
# 4            CloneA              0.0  HCT116bortezomib           B07
#
#   Metadata_clone_number  Metadata_plate_ID Metadata_plate_filename  \
# 0                   NaN                NaN                     NaN
# 1                   NaN                NaN                     NaN
# 2                   NaN                NaN                     NaN
# 3                   NaN                NaN                     NaN
# 4                   NaN                NaN                     NaN
#
#      Metadata_plate_map_name Metadata_treatment  Cells_AreaShape_Compactness  \
# 0  PlateMap_HCT116bortezomib                NaN                    -0.332570
# 1  PlateMap_HCT116bortezomib                NaN                    -0.299568
# 2  PlateMap_HCT116bortezomib                NaN                    -0.248175
# 3  PlateMap_HCT116bortezomib                NaN                     0.411564
# 4  PlateMap_HCT116bortezomib                NaN                     0.488648
#
#    ...  Nuclei_Texture_Correlation_DNA_10_03  \
# 0  ...                             -0.830788
# 1  ...                             -0.656543
# 2  ...                             -0.586268
# 3  ...                             -1.344829
# 4  ...                             -1.640214
#
#    Nuclei_Texture_Correlation_DNA_20_00  Nuclei_Texture_Correlation_DNA_20_03  \
# 0                             -0.374677                              0.616864
# 1                             -0.485547                              0.490874
# 2                             -0.563266                              0.357584
# 3                             -1.227813                             -0.622520
# 4                             -1.617616                             -0.637429
#
#    Nuclei_Texture_Correlation_ER_20_02  Nuclei_Texture_Correlation_Mito_10_01  \
# 0                            -0.563396                              -0.326782
# 1                            -0.724942                              -0.357694
# 2                            -0.602690                              -0.447640
# 3                            -1.267774                              -0.718975
# 4                            -1.178447                              -0.822978
#
#    Nuclei_Texture_Correlation_Mito_20_02  \
# 0                              -0.377877
# 1                              -0.464324
# 2                              -0.483970
# 3                              -0.764489
# 4                              -0.765152
#
#    Nuclei_Texture_Correlation_RNA_10_03  Nuclei_Texture_Correlation_RNA_20_00  \
# 0                             -1.430643                             -1.098005
# 1                             -0.899586                             -0.868361
# 2                             -0.560636                             -0.530838
# 3                             -1.059889                             -1.157662
# 4                             -0.942117                             -0.865444
#
#    Nuclei_Texture_Entropy_DNA_20_03  Nuclei_Texture_InfoMeas1_DNA_10_02
# 0                         -1.949559                            1.134156
# 1                         -1.102183                            0.879197
# 2                         -1.034590                            0.754502
# 3                         -1.124696                            1.191230
# 4                         -0.921934                            1.196038
#
# [5 rows x 283 columns]

# %%
output_file = os.path.join(output_dir, "all_merged_profiles.csv")
all_profiles_df.to_csv(output_file, index=False)

# %% [markdown]
# ## Generate Consensus Signatures

# %%
consensus_data = {}
for batch in profile_batches:
    meta_features = infer_cp_features(profile_batches[batch], metadata=True)
    meta_features = [x for x in meta_features if "well" not in x.lower()]
    
    consensus_df = modz(
        profile_batches[batch],
        replicate_columns = meta_features,
    )
    
    consensus_data[batch] = consensus_df.reset_index()

# %%
full_consensus_df = pd.concat(consensus_data.values(), sort=True).reset_index(drop=True)

meta_features = infer_cp_features(full_consensus_df, metadata=True)
cp_cols = infer_cp_features(full_consensus_df, metadata=False)

full_consensus_df = full_consensus_df.reindex(meta_features + cp_cols, axis="columns")

print(full_consensus_df.shape)
full_consensus_df.head()
# Out:
# (197, 4330)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate Metadata_clone_number  \
# 0            CloneA              0.0  HCT116bortezomib                   NaN
# 1            CloneA              0.7  HCT116bortezomib                   NaN
# 2            CloneA              7.0  HCT116bortezomib                   NaN
# 3            CloneA             70.0  HCT116bortezomib                   NaN
# 4            CloneE              0.0  HCT116bortezomib                   NaN
#
#    Metadata_plate_ID Metadata_plate_filename    Metadata_plate_map_name  \
# 0                NaN                     NaN  PlateMap_HCT116bortezomib
# 1                NaN                     NaN  PlateMap_HCT116bortezomib
# 2                NaN                     NaN  PlateMap_HCT116bortezomib
# 3                NaN                     NaN  PlateMap_HCT116bortezomib
# 4                NaN                     NaN  PlateMap_HCT116bortezomib
#
#   Metadata_treatment  Cells_AreaShape_Area  Cells_AreaShape_Center_X  ...  \
# 0                NaN             -0.893895                  0.255437  ...
# 1                NaN             -0.693841                 -0.270798  ...
# 2                NaN              0.907950                  0.905600  ...
# 3                NaN              0.974470                  0.107325  ...
# 4                NaN              0.012068                 -0.158300  ...
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                          -1.066815                          -1.064924
# 1                          -0.934510                          -0.929737
# 2                          -0.215912                          -0.212157
# 3                           0.608321                           0.585632
# 4                          -0.786629                          -0.783663
#
#    Nuclei_Texture_Variance_RNA_50_00  Nuclei_Texture_Variance_RNA_50_01  \
# 0                          -1.002073                          -0.982593
# 1                          -1.002195                          -0.963557
# 2                           0.022518                          -0.053756
# 3                           0.950771                           1.061018
# 4                          -0.721301                          -0.717333
#
#    Nuclei_Texture_Variance_RNA_50_02  Nuclei_Texture_Variance_RNA_50_03  \
# 0                          -0.999003                          -0.957047
# 1                          -0.989579                          -0.977990
# 2                           0.020729                          -0.046313
# 3                           0.943978                           1.004792
# 4                          -0.715175                          -0.695062
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 4330 columns]

# %%
consensus_df = feature_select(full_consensus_df, operation=feature_select_ops)

print(consensus_df.shape)
consensus_df.head()
# Out:
# (197, 239)
#   Metadata_CellLine  Metadata_Dosage    Metadata_Plate Metadata_clone_number  \
# 0            CloneA              0.0  HCT116bortezomib                   NaN
# 1            CloneA              0.7  HCT116bortezomib                   NaN
# 2            CloneA              7.0  HCT116bortezomib                   NaN
# 3            CloneA             70.0  HCT116bortezomib                   NaN
# 4            CloneE              0.0  HCT116bortezomib                   NaN
#
#    Metadata_plate_ID Metadata_plate_filename    Metadata_plate_map_name  \
# 0                NaN                     NaN  PlateMap_HCT116bortezomib
# 1                NaN                     NaN  PlateMap_HCT116bortezomib
# 2                NaN                     NaN  PlateMap_HCT116bortezomib
# 3                NaN                     NaN  PlateMap_HCT116bortezomib
# 4                NaN                     NaN  PlateMap_HCT116bortezomib
#
#   Metadata_treatment  Cells_AreaShape_Compactness  \
# 0                NaN                     0.457331
# 1                NaN                     0.717219
# 2                NaN                     0.189762
# 3                NaN                     1.966712
# 4                NaN                    -0.240478
#
#    Cells_AreaShape_Eccentricity  ...  Nuclei_Texture_Correlation_AGP_20_02  \
# 0                     -0.015568  ...                             -1.301552
# 1                      0.161159  ...                             -0.900436
# 2                      0.592850  ...                              0.632659
# 3                      1.670742  ...                              1.210730
# 4                     -0.147200  ...                             -0.969682
#
#    Nuclei_Texture_Correlation_AGP_20_03  Nuclei_Texture_Correlation_DNA_10_03  \
# 0                             -1.352057                             -1.410633
# 1                             -0.939445                             -1.174140
# 2                              0.739319                              0.404211
# 3                              1.183234                              1.038936
# 4                             -0.694606                             -0.841988
#
#    Nuclei_Texture_Correlation_DNA_20_03  \
# 0                             -0.257088
# 1                              0.304955
# 2                             -0.045157
# 3                              1.631791
# 4                             -1.070660
#
#    Nuclei_Texture_Correlation_Mito_10_01  \
# 0                              -0.918336
# 1                              -0.720160
# 2                               0.218847
# 3                               1.678181
# 4                              -1.122140
#
#    Nuclei_Texture_Correlation_Mito_20_02  \
# 0                              -0.838264
# 1                              -0.628171
# 2                               0.163968
# 3                               1.729909
# 4                              -0.910489
#
#    Nuclei_Texture_Correlation_RNA_10_03  Nuclei_Texture_Correlation_RNA_20_00  \
# 0                             -1.060417                             -1.019667
# 1                             -0.674569                             -0.514953
# 2                              1.223269                              1.006203
# 3                              1.111597                              1.101600
# 4                             -1.009617                             -1.175506
#
#    Nuclei_Texture_Entropy_DNA_20_03  Nuclei_Texture_InfoMeas1_DNA_10_01
# 0                         -1.004670                            1.076234
# 1                         -0.978249                            1.018162
# 2                          0.339973                            0.015188
# 3                          1.084341                           -0.797373
# 4                         -0.606870                            0.800610
#
# [5 rows x 239 columns]

# %%
output_gct_file = os.path.join(gct_dir, "consensus_feature_select.gct")
write_gct(profiles=consensus_df, output_file=output_gct_file)
