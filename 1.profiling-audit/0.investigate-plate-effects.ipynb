# %% [markdown]
# ## Inspect Plate Artifacts - Batch 3
#
# **Gregory Way, 2019**

# %%
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(platetools))
suppressPackageStartupMessages(library(ggplot2))

# %%
count_cells <- function(plate_name) {
    # Determine SQL file name
    project <- "2018_05_30_ResistanceMechanisms_Kapoor"
    bucket_dir <- file.path("~", "bucket", "projects", project, "workspace", "backend")
    sqlite_file <- file.path(bucket_dir, batch, plate_name, paste0(plate_name, ".sqlite"))
    
    # Setup a connection
    con <- RSQLite::dbConnect(drv = RSQLite::SQLite(),
                              dbname = sqlite_file)
    
    # Connect to image table
    image_df <- dplyr::tbl(
        con,
        dbplyr::sql("SELECT TableNumber, ImageNumber, Metadata_Plate, Metadata_Well from image")
    )
    
    # Connect to cells table
    cells_df <- dplyr::tbl(
        con,
        dbplyr::sql("SELECT TableNumber, ImageNumber from cells")
    )
    
    # Merge them together and count cells per well
    count_df <- cells_df %>%
        dplyr::inner_join(image_df,
                          by = c("TableNumber", "ImageNumber")) %>%
        dplyr::group_by(Metadata_Plate, Metadata_Well) %>%
        dplyr::count()
    
    return(count_df)
}

# %%
batch <- "2019_06_25_Batch3"
backend_dir <- file.path("..", "..", "backend", batch)

backend_folders = list.files(backend_dir, full.names = FALSE)

backend_files = list()
for (backend_file in backend_folders) {
    backend_files[[backend_file]] <-
        file.path(backend_dir, backend_file, paste0(backend_file, "_normalized_variable_selected.csv"))
}

backend_files
# Out:
# $MutClones
# [1] "../../backend/2019_06_25_Batch3/MutClones/MutClones_normalized_variable_selected.csv"
#
# $WTClones
# [1] "../../backend/2019_06_25_Batch3/WTClones/WTClones_normalized_variable_selected.csv"

# %% [markdown]
# ## Load Data

# %%
mut_df <- readr::read_csv(backend_files[["MutClones"]],
                          col_types=readr::cols())

print(dim(mut_df))
head(mut_df, 2)
# Out:
# [1]  57 191
#   Metadata_Plate Metadata_Well Metadata_Assay_Plate_Barcode
# 1 MutClones      B02           MutClones
# 2 MutClones      B03           MutClones
#   Metadata_Plate_Map_Name Metadata_well_position Metadata_clone_number
# 1 MutClones               B02                    BZ001
# 2 MutClones               B03                    BZ002
#   Cells_AreaShape_Compactness Cells_AreaShape_EulerNumber
# 1  0.6034418                  -3.05703
# 2 -1.0295421                  -1.41911
#   Cells_AreaShape_Extent Cells_AreaShape_FormFactor ⋯
# 1 0.05068862              0.6585738                 ⋯
# 2 1.11426953             -0.9345095                 ⋯
#   Nuclei_Texture_Correlation_AGP_20_00 Nuclei_Texture_Correlation_AGP_20_03
# 1  3.3582920                           1.126295
# 2 -0.3068762                           1.536572
#   Nuclei_Texture_Correlation_AGP_5_00 Nuclei_Texture_Correlation_ER_20_02
# 1  0.00000                            1.204256
# 2 -4.29316                            3.379792
#   Nuclei_Texture_Correlation_Mito_5_00 Nuclei_Texture_Correlation_RNA_20_02
# 1  0.4206682                           0.5705776
# 2 -6.8157241                           0.4181798
#   Nuclei_Texture_InfoMeas1_Mito_5_00
# 1 -1.320394
# 2  3.899485
#   Nuclei_Texture_InverseDifferenceMoment_AGP_20_02
# 1 -0.2247533
# 2  2.1667509
#   Nuclei_Texture_InverseDifferenceMoment_DNA_20_03
# 1 1.311671
# 2 2.502230
#   Nuclei_Texture_InverseDifferenceMoment_ER_20_02
# 1 0.212493
# 2 2.646517

# %%
wt_df <- readr::read_csv(backend_files[["WTClones"]],
                         col_types=readr::cols())

print(dim(wt_df))
head(wt_df, 2)
# Out:
# [1]  48 191
#   Metadata_Plate Metadata_Well Metadata_Assay_Plate_Barcode
# 1 WTClones       B02           WTClones
# 2 WTClones       B03           WTClones
#   Metadata_Plate_Map_Name Metadata_well_position Metadata_clone_number
# 1 WTClones                B02                    WT001
# 2 WTClones                B03                    WT001
#   Cells_AreaShape_Compactness Cells_AreaShape_EulerNumber
# 1 -0.68165560                  0.2433688
# 2  0.05125114                 -0.4970395
#   Cells_AreaShape_Extent Cells_AreaShape_FormFactor ⋯
# 1  0.5543276             0.27729305                 ⋯
# 2 -0.1045300             0.07257513                 ⋯
#   Nuclei_Texture_Correlation_AGP_20_00 Nuclei_Texture_Correlation_AGP_20_03
# 1 -1.992909                            -0.5624821
# 2 -1.922169                            -0.7716781
#   Nuclei_Texture_Correlation_AGP_5_00 Nuclei_Texture_Correlation_ER_20_02
# 1 -0.7311029                          -1.798579
# 2 -0.1594808                          -1.284761
#   Nuclei_Texture_Correlation_Mito_5_00 Nuclei_Texture_Correlation_RNA_20_02
# 1 -2.05401899                          -1.2708266
# 2  0.01782447                          -0.6921738
#   Nuclei_Texture_InfoMeas1_Mito_5_00
# 1  0.67166455
# 2 -0.06878273
#   Nuclei_Texture_InverseDifferenceMoment_AGP_20_02
# 1 -0.08257108
# 2 -0.44354985
#   Nuclei_Texture_InverseDifferenceMoment_DNA_20_03
# 1 0.4544209
# 2 0.2891828
#   Nuclei_Texture_InverseDifferenceMoment_ER_20_02
# 1 -0.6100711
# 2 -0.5773808

# %%
cor_file <- file.path("results", "WT_median_replicate_correlation.tsv")
wt_median_cor_df <- readr::read_tsv(cor_file, col_types = readr::cols())

cor_file <- file.path("results", "MUT_median_replicate_correlation.tsv")
mut_median_cor_df  <- readr::read_tsv(cor_file, col_types = readr::cols())

# %%
wt_median_cor_df <- wt_df %>%
    dplyr::select(Metadata_Well, Metadata_Plate_Map_Name, Metadata_clone_number) %>%
    dplyr::inner_join(wt_median_cor_df, by = "Metadata_clone_number")

mut_median_cor_df <- mut_df %>%
    dplyr::select(Metadata_Well, Metadata_Plate_Map_Name, Metadata_clone_number) %>%
    dplyr::inner_join(mut_median_cor_df, by = "Metadata_clone_number")

# %% [markdown]
# ## Count Cells Per Well
#
# Do not recalculate if the data already exist

# %%
# Mutant Clone Plate
mut_count_file <- file.path("results", "MutClones_cell_count_by_well.tsv")
if (!file.exists(mut_count_file)) {
    mut_count <- count_cells("MutClones") %>%
        dplyr::collect()
    mut_count %>% readr::write_tsv(mut_count_file)
} else {
    mut_count <- readr::read_tsv(mut_count_file, col_types=readr::cols())
}

# %%
head(mut_count)
# Out:
#   Metadata_Plate Metadata_Well n
# 1 MutClones      B02            9203
# 2 MutClones      B03           27543
# 3 MutClones      B04            8086
# 4 MutClones      B05           19640
# 5 MutClones      B06           20440
# 6 MutClones      B07           31643

# %%
# Wildtype Clone Plate
wt_count_file <- file.path("results", "WTClones_cell_count_by_well.tsv")
if (!file.exists(wt_count_file)) {
    wt_count <- count_cells("WTClones") %>%
        dplyr::collect()
    wt_count %>% readr::write_tsv(wt_count_file)
} else {
    wt_count <- readr::read_tsv(wt_count_file, col_types=readr::cols())
}

# %%
head(wt_count)
# Out:
#   Metadata_Plate Metadata_Well n
# 1 WTClones       B02           22129
# 2 WTClones       B03           21002
# 3 WTClones       B04           22375
# 4 WTClones       B05           14484
# 5 WTClones       B06           13674
# 6 WTClones       B07           12986

# %% [markdown]
# ## Visualize Platemaps

# %%
plate_mut_gg <- 
    platetools::raw_map(data = mut_df$Metadata_clone_number,
                        well = mut_df$Metadata_Well,
                        plate = 96) +
    ggtitle("Mutant Clones - Replicates") +
    theme_dark() +
    scale_fill_discrete() +
    theme(legend.position = "none")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_mut_replicates.png"))
ggsave(fig_file, height = 4, width = 6)

plate_mut_gg
# Out:
# plot without title

# %%
plate_wt_gg <- 
    platetools::raw_map(data = wt_df$Metadata_clone_number,
                        well = wt_df$Metadata_Well,
                        plate = 96) +
    ggtitle("Wild-type Clones - Replicates") +
    theme_dark() +
    scale_fill_discrete() +
    theme(legend.position = "none")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_wt_replicates.png"))
ggsave(fig_file, height = 4, width = 6)

plate_wt_gg
# Out:
# plot without title

# %% [markdown]
# ## Platemap for Cell Counts

# %%
cell_count_mut_gg <- 
    platetools::raw_map(data = mut_count$n,
                        well = mut_count$Metadata_Well,
                        plate = 96) +
    ggtitle("Mutant Clones - Cell Count") +
    theme_dark() +
    scale_fill_continuous(name = "Cells")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_mut_cell_counts.png"))
ggsave(fig_file, height = 4, width = 6)

cell_count_mut_gg
# Out:
# plot without title

# %%
cell_count_wt_gg <- 
    platetools::raw_map(data = wt_count$n,
                        well = wt_count$Metadata_Well,
                        plate = 96) +
    ggtitle("Wild-type Clones - Cell Count") +
    theme_dark() +
    scale_fill_continuous(name = "Cells")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_wt_cell_counts.png"))
ggsave(fig_file, height = 4, width = 6)

cell_count_wt_gg
# Out:
# plot without title

# %%
mut_median_cor_df
# Out:
#     Metadata_Well Metadata_Plate_Map_Name Metadata_clone_number replicate
# 1   B02           MutClones               BZ001                 False
# 2   B02           MutClones               BZ001                 True
# 3   B03           MutClones               BZ002                 False
# 4   B03           MutClones               BZ002                 True
# 5   B04           MutClones               BZ003                 False
# 6   B04           MutClones               BZ003                 True
# 7   B05           MutClones               BZ004                 False
# 8   B05           MutClones               BZ004                 True
# 9   B06           MutClones               BZ005                 False
# 10  B06           MutClones               BZ005                 True
# 11  B07           MutClones               BZ006                 False
# 12  B07           MutClones               BZ006                 True
# 13  B08           MutClones               BZ007                 False
# 14  B08           MutClones               BZ007                 True
# 15  B09           MutClones               BZ008                 False
# 16  B09           MutClones               BZ008                 True
# 17  B10           MutClones               BZ009                 False
# 18  B10           MutClones               BZ009                 True
# 19  B11           MutClones               BZ010                 False
# 20  B11           MutClones               BZ010                 True
# 21  C02           MutClones               BZ001                 False
# 22  C02           MutClones               BZ001                 True
# 23  C03           MutClones               BZ002                 False
# 24  C03           MutClones               BZ002                 True
# 25  C04           MutClones               BZ003                 False
# 26  C04           MutClones               BZ003                 True
# 27  C05           MutClones               BZ004                 False
# 28  C05           MutClones               BZ004                 True
# 29  C06           MutClones               BZ005                 False
# 30  C06           MutClones               BZ005                 True
# ⋮   ⋮             ⋮                       ⋮                     ⋮
# 85  F05           MutClones               BZ014                 False
# 86  F05           MutClones               BZ014                 True
# 87  F06           MutClones               BZ015                 False
# 88  F06           MutClones               BZ015                 True
# 89  F07           MutClones               BZ016                 False
# 90  F07           MutClones               BZ016                 True
# 91  F08           MutClones               BZ017                 False
# 92  F08           MutClones               BZ017                 True
# 93  F09           MutClones               BZ018                 False
# 94  F09           MutClones               BZ018                 True
# 95  F10           MutClones               WT_parental           False
# 96  F10           MutClones               WT_parental           True
# 97  G02           MutClones               BZ011                 False
# 98  G02           MutClones               BZ011                 True
# 99  G03           MutClones               BZ012                 False
# 100 G03           MutClones               BZ012                 True
# 101 G04           MutClones               BZ013                 False
# 102 G04           MutClones               BZ013                 True
# 103 G05           MutClones               BZ014                 False
# 104 G05           MutClones               BZ014                 True
# 105 G06           MutClones               BZ015                 False
# 106 G06           MutClones               BZ015                 True
# 107 G07           MutClones               BZ016                 False
# 108 G07           MutClones               BZ016                 True
# 109 G08           MutClones               BZ017                 False
# 110 G08           MutClones               BZ017                 True
# 111 G09           MutClones               BZ018                 False
# 112 G09           MutClones               BZ018                 True
# 113 G10           MutClones               WT_parental           False
# 114 G10           MutClones               WT_parental           True
#     correlation
# 1   -0.010724710
# 2    0.132758738
# 3   -0.006264252
# 4    0.562299515
# 5   -0.024972863
# 6    0.741824825
# 7   -0.027169157
# 8    0.247540844
# 9   -0.009941724
# 10   0.458814311
# 11  -0.006147448
# 12   0.999999901
# 13  -0.009978955
# 14   0.999961816
# 15  -0.031262954
# 16   0.721582024
# 17   0.003829710
# 18   0.464317705
# 19   0.011912865
# 20   0.084294085
# 21  -0.010724710
# 22   0.132758738
# 23  -0.006264252
# 24   0.562299515
# 25  -0.024972863
# 26   0.741824825
# 27  -0.027169157
# 28   0.247540844
# 29  -0.009941724
# 30   0.458814311
# ⋮   ⋮
# 85   0.01717639
# 86   0.91801973
# 87   0.21801688
# 88   0.68532222
# 89   0.01067576
# 90   0.39962712
# 91   0.16895188
# 92   0.63730579
# 93  -0.03054933
# 94   0.83243898
# 95  -0.02611334
# 96   0.99999948
# 97  -0.03789031
# 98   0.09809786
# 99   0.03135580
# 100  0.75296383
# 101  0.03238380
# 102  0.17695297
# 103  0.01717639
# 104  0.91801973
# 105  0.21801688
# 106  0.68532222
# 107  0.01067576
# 108  0.39962712
# 109  0.16895188
# 110  0.63730579
# 111 -0.03054933
# 112  0.83243898
# 113 -0.02611334
# 114  0.99999948

# %%
mut_replicate <- mut_median_cor_df %>% dplyr::filter(replicate == "True")

cor_mut_gg <- 
    platetools::raw_map(data = mut_replicate$correlation,
                        well = mut_replicate$Metadata_Well,
                        plate = 96) +
    ggtitle("Mutant Clones - Replicate Correlation") +
    theme_dark() +
    scale_fill_continuous(type = "viridis", name = "Pearson\nCorrelation")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_mut_replicate_correlation.png"))
ggsave(fig_file, height = 4, width = 6)

cor_mut_gg
# Out:
# plot without title

# %%
wt_replicate <- wt_median_cor_df %>% dplyr::filter(replicate == "True")

cor_wt_gg <- 
    platetools::raw_map(data = wt_replicate$correlation,
                        well = wt_replicate$Metadata_Well,
                        plate = 96) +
    ggtitle("Wild-type Clones - Replicate Correlation") +
    theme_dark() +
    scale_fill_continuous(type = "viridis", name = "Pearson\nCorrelation")

fig_file <- file.path("figures", "plate_effects", paste0(batch, "_wt_replicate_correlation.png"))
ggsave(fig_file, height = 4, width = 6)

cor_wt_gg
# Out:
# plot without title
